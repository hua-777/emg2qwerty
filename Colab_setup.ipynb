# %% [markdown]
# ### Step 1: Mount the Google Drive
#
# Remember to use GPU runtime before mounting your account. (Runtime --> Change runtime type).

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ### Step 2: Open the project directory
#
# Replace `Your_Dir` with your own path.

# %%
cd Your_Dir/emg2qwerty-main

# %% [markdown]
# ### Step 3: Install required packages
#
# After installing them, Colab will require you to restart the session.

# %%
# !pip install -r requirements.txt

# %% [markdown]
# ### Step 4: Start your experiments!
#
# - Remember to download the dataset here: `Your_Dir/emg2qwerty-main/data`.
# - You may now start your experiments with any scripts.
# - Below is an example of single-user training.

# %%
# !python -m emg2qwerty.train \
  user="single_user" \
  trainer.accelerator=gpu trainer.devices=1 \
  model=transformer_conv_ctc
# Out:
# [2025-03-05 00:24:44,439][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
# ...

# %%
# !python -m emg2qwerty.train \
  user="glob(single_user)" \
  checkpoint="'/home/winter/ECEC247/emg2qwerty/logs/2025-03-05/00-24-44/checkpoints/epoch=141-step=8520.ckpt'" \
  train=False trainer.accelerator=gpu trainer.devices=1 \
  decoder=ctc_greedy \
  hydra.launcher.mem_gb=16 \
  model=transformer_ctc \
  --multirun
# Out:
# [2025-03-05 01:54:05,903][HYDRA] Submitit 'local' sweep output dir : logs/2025-03-05/01-54-05
# [2025-03-05 01:54:05,904][HYDRA] 	#0 : user=single_user checkpoint='/home/winter/ECEC247/emg2qwerty/logs/2025-03-05/00-24-44/checkpoints/epoch=141-step=8520.ckpt' train=False trainer.accelerator=gpu trainer.devices=1 decoder=ctc_greedy model=transformer_conv_ctc
# Error executing job with overrides: ['user=single_user', "checkpoint='/home/winter/ECEC247/emg2qwerty/logs/2025-03-05/00-24-44/checkpoints/epoch=141-step=8520.ckpt'", 'train=False', 'trainer.accelerator=gpu', 'trainer.devices=1', 'decoder=ctc_greedy', 'model=transformer_conv_ctc']
# Traceback (most recent call last):
#   File "/home/winter/miniconda3/envs/emg2qwerty/lib/python3.10/site-packages/hydra/_internal/utils.py", line 220, in run_and_report
#     return func()
#   File "/home/winter/miniconda3/envs/emg2qwerty/lib/python3.10/site-packages/hydra/_internal/utils.py", line 466, in <lambda>
#     lambda: hydra.multirun(
# ...

# %%
# %load_ext tensorboard

# %tensorboard --logdir="/home/winter/ECEC247/emg2qwerty/logs/2025-03-05/00-24-44/lightning_logs"
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Reusing TensorBoard on port 6006 (pid 6106), started 0:00:24 ago. (Use '!kill 6106' to kill it.)
#       <iframe id="tensorboard-frame-d832ff567e382666" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-d832ff567e382666");
#           const url = new URL("http://localhost");
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# !kill 6106

# %%
# !python -m emg2qwerty.train \
  user="glob(single_user)" \
  checkpoint="'/home/winter/ECEC247/emg2qwerty/logs/2025-02-26/10-37-17/job0_trainer.devices=1,user=single_user/checkpoints/epoch=121-step=14640.ckpt'" \
  train=False trainer.accelerator=gpu trainer.devices=1 \
  decoder=ctc_greedy \
  hydra.launcher.mem_gb=16 \
  model=tds_conv_ctc \
  --multirun
# Out:
# [2025-03-05 02:01:44,794][HYDRA] Submitit 'local' sweep output dir : logs/2025-03-05/02-01-44
# [2025-03-05 02:01:44,795][HYDRA] 	#0 : user=single_user checkpoint='/home/winter/ECEC247/emg2qwerty/logs/2025-02-26/10-37-17/job0_trainer.devices=1,user=single_user/checkpoints/epoch=121-step=14640.ckpt' train=False trainer.accelerator=gpu trainer.devices=1 decoder=ctc_greedy model=tds_conv_ctc

# %%
# !python -m emg2qwerty.train \
  user="glob(single_user)" \
  checkpoint="'/home/winter/ECEC247/emg2qwerty/logs/2025-03-05/00-24-44/checkpoints/epoch=141-step=8520.ckpt'" \
  train=False trainer.accelerator=gpu trainer.devices=1 \
  decoder=ctc_greedy \
  hydra.launcher.mem_gb=16 \
  model=transformer_ctc \
  --multirun
# Out:
# [2025-03-05 02:10:38,451][HYDRA] Submitit 'local' sweep output dir : logs/2025-03-05/02-10-38
# [2025-03-05 02:10:38,452][HYDRA] 	#0 : user=single_user checkpoint='/home/winter/ECEC247/emg2qwerty/logs/2025-03-05/00-24-44/checkpoints/epoch=141-step=8520.ckpt' train=False trainer.accelerator=gpu trainer.devices=1 decoder=ctc_greedy model=transformer_ctc
# Error executing job with overrides: ['user=single_user', "checkpoint='/home/winter/ECEC247/emg2qwerty/logs/2025-03-05/00-24-44/checkpoints/epoch=141-step=8520.ckpt'", 'train=False', 'trainer.accelerator=gpu', 'trainer.devices=1', 'decoder=ctc_greedy', 'model=transformer_ctc']
# Traceback (most recent call last):
#   File "/home/winter/miniconda3/envs/emg2qwerty/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/home/winter/miniconda3/envs/emg2qwerty/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
# ...

# %%
import os

os.environ['HYDRA_FULL_ERROR'] = '1'
